# %% [markdown]
# # Demand Forecasting
#
# This notebook explains the demand forecasting workflow for predicting the next day's product demand at store-product level.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 200)

# %%
daily_features = pd.read_csv(ROOT / 'data/features/daily_store_product_features.csv', parse_dates=['sales_date'])
report_path = ROOT / 'models/demand_forecasting/demand_forecasting_report.md'
metadata = pd.read_json(ROOT / 'models/demand_forecasting/model_metadata.json')
daily_features.head()

# %% [markdown]
# ## Forecasting target
#
# The target column is `target_next_day_units`, which means the model predicts how many units of a product will be sold on the next day in a specific store.

# %%
coefficients = pd.read_csv(ROOT / 'models/demand_forecasting/ridge_coefficients.csv')
coefficients.head(15)

# %%
predictions = pd.read_csv(ROOT / 'models/demand_forecasting/test_predictions.csv')
predictions.head(10)

# %% [markdown]
# ## Interpretation
#
# Compare the naive baseline with the ridge model. The thesis result is stronger because the model was evaluated against a simple baseline rather than being reported without context.
