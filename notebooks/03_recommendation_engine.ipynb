# %% [markdown]
# # Recommendation Engine
#
# This notebook explains the market-basket recommendation workflow. It recommends products based on items that are frequently purchased together.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 200)

# %%
association_rules = pd.read_csv(ROOT / 'models/recommendation_engine/association_rules.csv')
evaluation = pd.read_csv(ROOT / 'models/recommendation_engine/evaluation_metrics.csv')
examples = pd.read_csv(ROOT / 'models/recommendation_engine/recommendation_examples.csv')
association_rules.head()

# %% [markdown]
# ## Recommendation logic
#
# If customers often buy two products together, the engine learns that co-purchase relation and recommends one when the other appears in the basket.

# %%
evaluation

# %%
examples.head(10)

# %% [markdown]
# ## Interpretation
#
# Focus on `Hit Rate@K` and `MRR`. These show whether the true next item appears in the recommended list and how early it appears.
