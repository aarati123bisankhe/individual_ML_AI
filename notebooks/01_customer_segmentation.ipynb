# %% [markdown]
# # Customer Segmentation
#
# This notebook explains the customer segmentation workflow for the smart grocery app. It uses the engineered customer feature table and the saved model outputs.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 200)

# %%
customer_features = pd.read_csv(ROOT / 'data/features/customer_features.csv')
segment_summary = pd.read_csv(ROOT / 'models/customer_segmentation/segment_summary.csv')
segments = pd.read_csv(ROOT / 'models/customer_segmentation/customer_segments.csv')
customer_features.head()

# %% [markdown]
# ## Why segmentation matters
#
# Customer segmentation helps the supermarket group customers into meaningful profiles such as high-value buyers, regular digital shoppers, and low-engagement customers. These segments can later support recommendations, targeted offers, and management insights.

# %%
segment_summary

# %%
segments['segment_name'].value_counts().rename_axis('segment_name').reset_index(name='customer_count')

# %% [markdown]
# ## Interpretation
#
# Look at transaction count, total spend, basket size, app usage, and recency. These features explain why a segment is valuable, digital, occasional, or dormant.
