# %% [markdown]
# # Scan-to-Pay Anomaly Detection
#
# This notebook explains the anomaly detection workflow for suspicious or problematic scan-to-pay transactions.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 200)

# %%
transaction_features = pd.read_csv(ROOT / 'data/features/transaction_features.csv')
anomaly_scores = pd.read_csv(ROOT / 'models/scan_to_pay_anomaly_detection/test_anomaly_scores.csv')
validation_metrics = pd.read_csv(ROOT / 'models/scan_to_pay_anomaly_detection/validation_metrics.csv')
test_metrics = pd.read_csv(ROOT / 'models/scan_to_pay_anomaly_detection/test_metrics.csv')
transaction_features.head()

# %% [markdown]
# ## Anomaly idea
#
# A transaction becomes suspicious when it shows unusual combinations of rescans, failed scans, retries, payment failures, slow scan durations, or high payment latency.

# %%
validation_metrics

# %%
test_metrics

# %%
anomaly_scores.head(10)

# %% [markdown]
# ## Interpretation
#
# This model is best treated as a ranked alerting model. The most useful result is how concentrated true anomalies are among the top flagged transactions.
